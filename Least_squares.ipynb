# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate data
# x: random number -10 to 10
# y:
# $$
# 2 \cos x + \frac{1}{2}x
# $$
#
# Our goal is estimate θ_n:
# $$
# θ_1 \cos x + θ_2x
# $$

# %%
x = np.arange(-10, 10, 0.1)
y = 2*np.cos(x) + (1/2)*x

# %%
plt.plot(x, y)

# %%
# add random number
y = 2*np.cos(x) + (1/2)*x + np.random.normal(0.0, 1.0, len(x))

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Least squares

# %%
# generate dataset
n = 2
X = np.zeros((len(x), n), float)

X[:, 0] = np.cos(x)
X[:, 1] = x + np.random.normal(0.0, 0.5, len(x))

# %%
# estimate θ
theta, residuals, rank, s = np.linalg.lstsq(X, y, rcond=None)

# %%
theta
# Out:
# array([2.15586128, 0.50308277])

# %%
plt.figure(dpi=100)
plt.scatter(x, y)
plt.plot(x, 2*np.cos(x) + (1/2)*x, 'kx')
plt.plot(x, theta[0]*np.cos(x) + (theta[1])*x, 'r')
